# %%
import pandas as pd

dat = pd.read_excel("./Домашнее задание.xls")

# %%
dat
# Out:
#           Дата  Пользователи  Новые пользователи  Доля новых пользователей  \
# 0   2017-12-31         23095                1603                  0.069409
# 1   2017-12-30         29918                2116                  0.070727
# 2   2017-12-29         38953                3029                  0.077760
# 3   2017-12-28         41326                3228                  0.078111
# 4   2017-12-27         34148                2199                  0.064396
# ..         ...           ...                 ...                       ...
# 120 2017-09-02         20306                1746                  0.085984
# 121 2017-09-01         22125                2258                  0.102056
# 122 2017-08-31         23735                2333                  0.098294
# 123 2017-08-30         21569                1816                  0.084195
# 124 2017-08-29         31793                1790                  0.056302
#
# ...

# %%
dat.corr()
# Out:
#                                                 Пользователи  \
# Пользователи                                        1.000000
# Новые пользователи                                  0.734401
# Доля новых пользователей                           -0.063164
# Количество платящих пользователей                   0.842289
# Количество платящих пользователей.1                 0.842289
# Количество покупок                                  0.841564
# Количество покупок.1                                0.841564
# Количество покупок на платящего пользователя        0.357802
# Выручка, RUB                                        0.838978
# Средняя выручка на пользователя, RUB                0.748435
# Средняя выручка на платящего пользователя, RUB      0.654097
# Вернувшиеся                                         0.996110
# Выручка, RUB.1                                      0.838978
# CR воронки покупок, %                               0.334832
# ...

# %% [markdown]
# Бизнес метрика - Выручка, RUB.1.
# Экономические метрики - Пользователи, Новые пользователи, Количество платящих пользователей, Количество покупок на платящего пользователя, Выручка, RUB, Средняя выручка на пользователя, Средняя выручка на платящего пользователя.
# Продуктовые метрики - Доля новых пользователей, Количество платящих пользователей.1, CR воронки покупок, Ошибки, CSI, Количество покупок.1
#
# Выручка зависит от количества пользователей, которые платят, т.е. кол-во пользователей * средний чек. По имеющимся данным корреляция между выручкой и пользователями очень сильная (более 0.8).
