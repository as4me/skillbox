# %% [markdown]
# # Курсовая работа. Блок 1
# *Pandas и Matplotlib*
#
# **NB!** Код должен быть с комментариями к каждому логическому блоку кода. В противном случае работа **не** будет принята. <br><br>
# Выполнение курсовой работы может потребовать использование дополнительных библиотек.
#
# <br><br>
# **Описание работы:**
#
# Перед вами стоит бизнес-задача – на основании имеющихся данных подготовить аналитический отчет, который в дальнейшем поможет продюсерам образовательных программ эффективно выстраивать стратегию по модернизированию и улучшению курсов. В начале отчета предлагается оформить емкий описательный блок по каждому курсу на основании рассчитанных показателей. Далее предлагается посчитать потенциальную нагрузку на преподавателей, чтобы оценить необходимость расширения штата сотрудников. Затем идет блок из двух пунктов по анализу качества контента курсов, где необходимо выявить проблемные модули, которые, возможно, требуют доработки. Также стоит задача выявить потенциальную сезонность. Наконец, предложено задание для самостоятельной разработки метрики успеваемости студентов для нахождения тех, кто значительно хуже справляются с прохождением курса. Каждый из пунктов анализа предполагается сопроводить аналитическим выводом на основании рассчитанных метрик.
#
# <br><br>
#
# _________
# Обозначения:<br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(p)** – задание может быть выполнено после прохождения модулей по Pandas <br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(m)** – задание может быть выполнено после прохождения модуля по Matplotlib <br>
# &nbsp;&nbsp;&nbsp;&nbsp;⭐ – необязательное задание повышенной сложности
# _________
#
# [Codebook](#Codebook) <br>
# [1. Описание и начальная работа с данными](#1.1-Описание-и-начальная-работа-с-данными)<br>
# [2. Расчет потенциальной нагрузки на преподавателей](#2.-Расчет-потенциальной-нагрузки-на-преподавателей)<br>
# [3. Выявление проблемных модулей](#3.-Выявление-проблемных-модулей)<br>
# [4. Расчет конверсии](#4.-Расчет-конверсии) <br>
# [5. Метрика успеваемости ](#5.-Метрика-успеваемости)

# %% [markdown]
# ## Codebook
#
# `courses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `title` – название курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `field` – сфера, к которой относится курс <br> <br><br>
# `students.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `city` – город студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `birthday` – день рождения студента <br> <br><br>
# `course_contents.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `course_id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `module_title` – название модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_title` – название урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_token` – токен урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `is_video` – наличие видео *(true/false)* <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `is_homework` – наличие домашней работы *(true/false)* <br>
# <br><br>
# `progresses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `student_id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `course_id` – идентификатор курса <br> <br><br>
# `progress_phases.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `progress_id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `status` – статус прохождения урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `start_date` – дата начала <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `finish_date` – дата окончания <br>
# <br><br>

# %% [markdown]
# ## 1. Описание и начальная работа с данными
#
# Вам необходимо подготовить данные и описать их. Данные реальные и содержат пропущенные значения, а также лишние относительно друг друга данные. <br>
#
# Объедините датасеты (кроме `students.scv`) в один общий для дальнейшей работы. Отдельный датасет создайте для расчета среднего возраста студентов курсов (отдельный датасет со `students.scv` нужен, чтобы в основном не потерять значения в основном датасете из-за того, что не по всем студентам есть анкетные данные о дате рождения). <br> <br>
# Опишите данные: <br>
# 1. **(p)** Посчитайте
#       * общее количество курсов в датасете,
#       * количество модулей на каждом курсе,
#       * количество уроков в каждом модуле на каждом курсе,
#       * медианное количество уроков в модуле на каждом курсе,
#       * количество учеников на каждом курсе
#       * минимальный, максимальный, средний, медианный возраст студентов
#       * минимальный, максимальный, средний, медианный возраст студентов на каждом курсе
# 2. **(m)** Постройте bar-chart, отражающий количество студентов на каждом курсе. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий количество студентов на каждом курсе. График должен иметь заголовок. Значения должны быть отсортированы. Цвет столбцов должен содержать информацию о сфере, к которой относится курс (то есть нужна легенда). Прозрачность должна стоять на отметке 0.1. На график должна быть нанесена линия медианы. У медианы должен быть свой цвет. Рамки у графика быть не должно ⭐
# 4.     На основании рассчитанных значений опишите данные (описание должно быть полным и покрывать все полученные выше метрики)
#
# _____________________________________________________________________

# %% [markdown]
# Для того, чтобы проверить, что вы правильно соединили все датасеты в основной (без `students.csv`), запустите аналогичный приведенному ниже запрос. Выдача должна совпадать. Имейте в виду, что названия некоторых столбцов были переименованы.

# %%
import pandas as pd
from matplotlib import pyplot as pt
import numpy as np

from datetime import datetime
dateparse = lambda x: datetime.strptime(x, '%d/%m/%Y')
# Парсим данные 
dt_courses = pd.read_csv('Data_1/Data/courses.csv',index_col=0)
dt_courses.rename(columns={'id': 'course_id','title':'course_title'}, inplace=True)
dt_course_contents = pd.read_csv('Data_1/Data/course_contents.csv')
dt_progresses = pd.read_csv('Data_1/Data/progresses.csv')
dt_progresses.rename(columns={'id':'progress_id'},inplace=True)
dt_progress_phases = pd.read_csv('Data_1/Data/progress_phases.csv',date_parser=['start_date','finish_date'],dayfirst=False)
dt_students = pd.read_csv('Data_1/Data/students.csv')

dt_students = dt_students.dropna()

# %%
dt_students["birthday"]= pd.to_datetime(dt_students["birthday"], errors = 'coerce')

# %%
#объединяем 2 датафрейма с курсами и описанием курсов по их ID
dt_main1 = pd.merge(dt_courses,dt_course_contents,on='course_id',how='left')
dt_main1.head()
# Out:
#                           course_id             course_title        field  \
# 0  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 1  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 2  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 3  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 4  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
#
#    module_number    module_title  lesson_number  \
# 0              1  Вводный модуль              1
# 1              1  Вводный модуль              2
# 2              1  Вводный модуль              3
# 3              1  Вводный модуль              4
# 4              1  Вводный модуль              5
#
#                       lesson_title                          lesson_token  \
# 0           Какие бывают программы  cf394764-8850-4a0a-8d02-03470fe5345c
# 1  Где и для чего применяется Java  b3c2b829-aa3f-4607-a829-b74b69071b19
# 2     Как выглядит программный код  c25eac6e-b6bb-4de6-957f-f077f07856fc
# 3       Установка среды разработки  0ac58921-5765-40aa-aec9-544f8313e3f6
# 4    Исправляем готовое приложение  b28da8d8-0a6e-40bd-b01d-d529d1ad260d
#
#    is_video  is_homework
# 0      True        False
# 1      True        False
# 2      True        False
# 3      True        False
# 4      True        False

# %%
# добавляем прогресс
dt_main2 = pd.merge(dt_progresses,dt_progress_phases,on='progress_id',how='left')
dt_main2.head()
# Out:
#                         progress_id                        student_id  \
# 0  8459fbc07e32ec92bd7b43d7df9bfa89  a6ae278c0eab719b3784e5ea147c128f
# 1  8459fbc07e32ec92bd7b43d7df9bfa89  a6ae278c0eab719b3784e5ea147c128f
# 2  8459fbc07e32ec92bd7b43d7df9bfa89  a6ae278c0eab719b3784e5ea147c128f
# 3  8459fbc07e32ec92bd7b43d7df9bfa89  a6ae278c0eab719b3784e5ea147c128f
# 4  a9d173142534e33ce39146017f9c6835  e24062de06d301937b3b3a8e383e3e21
#
#                           course_id  module_number  lesson_number status  \
# 0  0770b1b039964228294f1f34b29fc2c1            4.0            3.0   done
# 1  0770b1b039964228294f1f34b29fc2c1            4.0            2.0   done
# 2  0770b1b039964228294f1f34b29fc2c1            4.0            1.0   done
# 3  0770b1b039964228294f1f34b29fc2c1            1.0            1.0   done
# 4  bf27a4bf4ada4c756451703ea62a914f            1.0            6.0   done
#
#                       start_date                    finish_date
# 0  2018-02-19 19:21:25.013391+00  2018-02-20 08:46:02.029132+00
# 1  2018-02-19 19:21:25.002537+00  2018-02-20 08:46:02.022666+00
# 2  2018-02-19 19:21:24.985811+00  2018-02-20 08:46:02.007429+00
# 3         2018-02-06 21:47:41+00         2018-02-06 14:32:40+00
# 4         2018-01-16 20:34:50+00         2018-01-17 20:13:32+00

# %%
dt_main = pd.merge(dt_main1,dt_main2,on=['course_id','lesson_number','module_number'],how='left')
dt_main.head()
# Out:
#                           course_id             course_title        field  \
# 0  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 1  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 2  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 3  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
# 4  943306102e5b067d08a29094f37b8193  Java-разработчик c нуля  Development
#
#    module_number    module_title  lesson_number            lesson_title  \
# 0              1  Вводный модуль              1  Какие бывают программы
# 1              1  Вводный модуль              1  Какие бывают программы
# 2              1  Вводный модуль              1  Какие бывают программы
# 3              1  Вводный модуль              1  Какие бывают программы
# 4              1  Вводный модуль              1  Какие бывают программы
#
#                            lesson_token  is_video  is_homework  \
# 0  cf394764-8850-4a0a-8d02-03470fe5345c      True        False
# 1  cf394764-8850-4a0a-8d02-03470fe5345c      True        False
# 2  cf394764-8850-4a0a-8d02-03470fe5345c      True        False
# 3  cf394764-8850-4a0a-8d02-03470fe5345c      True        False
# 4  cf394764-8850-4a0a-8d02-03470fe5345c      True        False
#
#                         progress_id                        student_id status  \
# 0  45cdf025b87db75e84f93c4ac3ccb5c7  0b4656b84ca60350583f8fbe236dda86   done
# 1  0c56109dde49080e7441e95b22bb73c2  1d874e6b6bdc34559781f65f9f761791   done
# 2  36079c0615d85f3cebfa47542b43ab41  ab7f5c720e3a5e1de00c2cdbef19fbf0   done
# 3  37384cbeb141835cc61b5fd22abd9200  29ab3f8c52a858bea2d3b9a51c433578   done
# 4  3a79d622c4057c1c029c74e282e43396  72afe01498ba14045467fc32029b650c   done
#
#                       start_date                    finish_date
# 0  2019-03-29 17:02:32.838469+00  2019-04-13 17:32:19.134874+00
# 1  2019-06-13 19:22:19.331201+00  2019-06-13 19:51:21.987534+00
# 2  2019-03-27 06:56:51.138795+00  2019-03-27 06:56:54.834751+00
# 3  2019-05-28 11:09:29.320478+00  2019-05-29 06:47:21.794092+00
# 4  2019-03-24 07:03:03.582679+00  2019-03-24 09:50:32.595199+00

# %%
dt_main[dt_main.student_id == "768c2987a744c51ce64a5993a2a94eaf"]
# Out:
#                                course_id          course_title        field  \
# 96372   e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля  Development
# 97338   e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля  Development
# 97948   e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля  Development
# 98518   e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля  Development
# 99076   e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля  Development
# 99616   e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля  Development
# 100144  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля  Development
# 116533  04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов       Design
# 117131  04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов       Design
# 117511  04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов       Design
# 117853  04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов       Design
# 118136  04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов       Design
# 118413  04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов       Design
# 122470  c9fcb746d51e41bc5a217002d081454b    Веб-дизайн PRO 2.0       Design
# 124181  c9fcb746d51e41bc5a217002d081454b    Веб-дизайн PRO 2.0       Design
# 125152  c9fcb746d51e41bc5a217002d081454b    Веб-дизайн PRO 2.0       Design
# 125975  c9fcb746d51e41bc5a217002d081454b    Веб-дизайн PRO 2.0       Design
# 126742  c9fcb746d51e41bc5a217002d081454b    Веб-дизайн PRO 2.0       Design
# 127466  c9fcb746d51e41bc5a217002d081454b    Веб-дизайн PRO 2.0       Design
# 128169  c9fcb746d51e41bc5a217002d081454b    Веб-дизайн PRO 2.0       Design
# 128741  c9fcb746d51e41bc5a217002d081454b    Веб-дизайн PRO 2.0       Design
# 129292  c9fcb746d51e41bc5a217002d081454b    Веб-дизайн PRO 2.0       Design
# 129832  c9fcb746d51e41bc5a217002d081454b    Веб-дизайн PRO 2.0       Design
# 130358  c9fcb746d51e41bc5a217002d081454b    Веб-дизайн PRO 2.0       Design
# 139740  dad6f6ffc086caa89e2f40c28a9c7490             UX-дизайн       Design
#
#         module_number                                       module_title  \
# 96372               1                                Знакомство с языком
# 97338               1                                Знакомство с языком
# 97948               1                                Знакомство с языком
# 98518               1                                Знакомство с языком
# 99076               1                                Знакомство с языком
# 99616               1                                Знакомство с языком
# 100144              1                                Знакомство с языком
# 116533              1  Введение в Motion Design. Тренды, разновидност...
# 117131              1  Введение в Motion Design. Тренды, разновидност...
# 117511              1  Введение в Motion Design. Тренды, разновидност...
# 117853              2        12 принципов анимации от Walt Disney Studio
# 118136              2        12 принципов анимации от Walt Disney Studio
# 118413              2        12 принципов анимации от Walt Disney Studio
# 122470              1            Специализация и личное позиционирование
# 124181              1            Специализация и личное позиционирование
# 125152              1            Специализация и личное позиционирование
# 125975              1            Специализация и личное позиционирование
# 126742              1            Специализация и личное позиционирование
# 127466              1            Специализация и личное позиционирование
# 128169              2                              Концептуальный дизайн
# 128741              2                              Концептуальный дизайн
# 129292              2                              Концептуальный дизайн
# 129832              2                              Концептуальный дизайн
# 130358              2                              Концептуальный дизайн
# 139740              1       Профессия дизайнера в эпоху цифровых перемен
#
#         lesson_number                                       lesson_title  \
# 96372               1                                              Интро
# 97338               2    Что умеет JavaScript и почему он так популярен?
# 97948               3                           Инструменты разработчика
# 98518               4                                      Hello, world!
# 99076               5                                    Синтаксис языка
# 99616               6                                              Аутро
# 100144              7                                    Домашняя работа
# 116533              1                                         Знакомство
# 117131              2  Введение в Motion Design. Тренды, разновидност...
# 117511              3                                    Домашняя работа
# 117853              1                                              Интро
# 118136              2                              12 принципов анимации
# 118413              3                                    Домашняя работа
# 122470              1                                        Интро курса
# 124181              2                                      Специализация
# 125152              3                                Домашнее задание #1
# 125975              4                            Личное позиционирование
# 126742              5                                Домашнее задание #2
# 127466              6                                    Домашняя работа
# 128169              1                               Брифинг от заказчика
# 128741              2                    Что такое концептуальный дизайн
# 129292              3                        Практика — дизайн-концепция
# 129832              4                                  Практика — мокапы
# 130358              5                                    Домашняя работа
# 139740              1                                        Приветствие
#
#                                 lesson_token  is_video  is_homework  \
# 96372   0d4678b0-abfe-4132-9193-97f9b0f08d3a      True        False
# 97338   6af5b93a-593b-48a0-bb03-42fa2571ede5      True        False
# 97948   460c54ea-d899-44d3-8940-00302ff5f2e5      True        False
# 98518   73315f69-8587-4f46-ab6b-fe57c8f1aa52      True        False
# 99076   fe10ef7f-44cb-4184-b06f-d7c38b0e81a5      True        False
# 99616   efe6a65b-a9a2-4d3a-910a-750e72c3f118      True        False
# 100144  af6e818e-08f0-4e32-981e-95a35395ee8f     False         True
# 116533  aa344de3-1191-4e69-b485-61823118f71c      True        False
# 117131  246c8429-dd18-4f3a-a9fb-d3c07e7d6912      True        False
# 117511  c4377574-d117-45c7-8da5-dd7d1923517d     False         True
# 117853  7ea16a2d-e6d1-4158-907f-ae0ce8379c45      True        False
# 118136  7eea2930-11db-45c9-a16c-0d800b6dc99d      True        False
# 118413  f6f37ada-7763-4a06-9e45-a42ca568e69a     False         True
# 122470  df1a1f20-cdf7-443d-b25b-0a4b990b84d9      True        False
# 124181  558acc64-3867-4ada-ac6f-36e9a7922f68      True        False
# 125152  a3d74174-08be-4634-949a-108d4f915fa6      True        False
# 125975  9dd50916-4aa6-4a73-b86c-56a1bd7753c8      True        False
# 126742  7ea421f0-04b5-4df8-a76c-03e24692eba9      True        False
# 127466  43e1fbdd-1ee9-4ed5-a577-4dadd80c02b3     False         True
# 128169  a25caa09-95d0-4e0c-b3c0-ad15f23bead8      True        False
# 128741  f23b1890-9365-406f-816b-04864cefe58f      True        False
# 129292  beb5abe6-b101-4003-a5ed-a87add92210a      True        False
# 129832  7df8adef-1259-4b72-9bf2-353c73389d06      True        False
# 130358  90c5f618-e9f3-4af8-96ab-f41b312bfa77     False         True
# 139740  86d0d49c-5590-4c0b-8fca-927191bb3fd5      True        False
#
#                              progress_id                        student_id  \
# 96372   c90ebe1431eac5cbb11692100b7a0f8d  768c2987a744c51ce64a5993a2a94eaf
# 97338   c90ebe1431eac5cbb11692100b7a0f8d  768c2987a744c51ce64a5993a2a94eaf
# 97948   c90ebe1431eac5cbb11692100b7a0f8d  768c2987a744c51ce64a5993a2a94eaf
# 98518   c90ebe1431eac5cbb11692100b7a0f8d  768c2987a744c51ce64a5993a2a94eaf
# 99076   c90ebe1431eac5cbb11692100b7a0f8d  768c2987a744c51ce64a5993a2a94eaf
# 99616   c90ebe1431eac5cbb11692100b7a0f8d  768c2987a744c51ce64a5993a2a94eaf
# 100144  c90ebe1431eac5cbb11692100b7a0f8d  768c2987a744c51ce64a5993a2a94eaf
# 116533  5767046d89ed7563a0c3a9a3896a23e6  768c2987a744c51ce64a5993a2a94eaf
# 117131  5767046d89ed7563a0c3a9a3896a23e6  768c2987a744c51ce64a5993a2a94eaf
# 117511  5767046d89ed7563a0c3a9a3896a23e6  768c2987a744c51ce64a5993a2a94eaf
# 117853  5767046d89ed7563a0c3a9a3896a23e6  768c2987a744c51ce64a5993a2a94eaf
# 118136  5767046d89ed7563a0c3a9a3896a23e6  768c2987a744c51ce64a5993a2a94eaf
# 118413  5767046d89ed7563a0c3a9a3896a23e6  768c2987a744c51ce64a5993a2a94eaf
# 122470  a387ab916f402cb3fbfffd29f68fd0ce  768c2987a744c51ce64a5993a2a94eaf
# 124181  a387ab916f402cb3fbfffd29f68fd0ce  768c2987a744c51ce64a5993a2a94eaf
# 125152  a387ab916f402cb3fbfffd29f68fd0ce  768c2987a744c51ce64a5993a2a94eaf
# 125975  a387ab916f402cb3fbfffd29f68fd0ce  768c2987a744c51ce64a5993a2a94eaf
# 126742  a387ab916f402cb3fbfffd29f68fd0ce  768c2987a744c51ce64a5993a2a94eaf
# 127466  a387ab916f402cb3fbfffd29f68fd0ce  768c2987a744c51ce64a5993a2a94eaf
# 128169  a387ab916f402cb3fbfffd29f68fd0ce  768c2987a744c51ce64a5993a2a94eaf
# 128741  a387ab916f402cb3fbfffd29f68fd0ce  768c2987a744c51ce64a5993a2a94eaf
# 129292  a387ab916f402cb3fbfffd29f68fd0ce  768c2987a744c51ce64a5993a2a94eaf
# 129832  a387ab916f402cb3fbfffd29f68fd0ce  768c2987a744c51ce64a5993a2a94eaf
# 130358  a387ab916f402cb3fbfffd29f68fd0ce  768c2987a744c51ce64a5993a2a94eaf
# 139740  6407c290505e790e92207a1dbc41a2cd  768c2987a744c51ce64a5993a2a94eaf
#
#        status                     start_date                    finish_date
# 96372    done  2018-06-19 10:40:05.063485+00  2018-06-19 14:56:16.346353+00
# 97338    done  2018-06-19 14:56:16.570129+00  2018-06-19 15:08:13.930725+00
# 97948    done  2018-06-19 15:08:14.103923+00  2018-06-19 15:39:53.661163+00
# 98518    done  2018-06-19 15:39:53.923777+00    2018-06-19 18:10:52.1737+00
# 99076    done  2018-06-19 18:10:52.316728+00  2018-06-19 18:35:38.720317+00
# 99616    done  2018-06-19 18:35:38.884217+00  2018-06-19 18:37:11.155066+00
# 100144  start  2018-06-19 18:40:00.576904+00                            NaN
# 116533   done         2018-01-13 15:20:23+00         2018-01-13 15:20:23+00
# 117131   done         2018-01-13 15:20:23+00         2018-01-14 13:47:25+00
# 117511   done  2018-02-19 12:32:35.928905+00  2018-02-20 09:16:36.741375+00
# 117853   done  2018-02-22 08:54:10.987784+00  2018-02-22 08:57:30.914939+00
# 118136   done  2018-02-22 08:57:31.008346+00  2018-04-28 13:45:40.708228+00
# 118413   fail  2018-04-28 13:45:40.955076+00                            NaN
# 122470   done  2018-06-20 14:25:21.783762+00  2018-06-20 15:45:07.717209+00
# 124181   done  2018-06-20 15:45:07.976223+00  2018-06-20 15:58:21.886722+00
# 125152   done  2018-06-20 15:58:22.132468+00  2018-06-20 16:00:06.127191+00
# 125975   done   2018-06-20 16:00:06.36178+00  2018-06-21 19:09:30.845034+00
# 126742   done  2018-06-21 19:09:31.117521+00  2018-06-21 19:10:36.707919+00
# 127466   done  2018-06-21 19:10:36.957891+00  2018-06-28 15:59:25.320418+00
# 128169   done  2018-06-23 08:18:07.476199+00  2018-06-23 08:18:09.552181+00
# 128741   done  2018-06-23 08:18:09.653771+00  2018-06-23 08:18:12.784616+00
# 129292   done  2018-06-23 08:18:12.890698+00  2018-06-23 08:28:50.564437+00
# 129832   done  2018-06-23 08:28:50.681065+00  2018-06-23 08:28:52.439542+00
# 130358  start  2018-06-23 08:31:00.338883+00                            NaN
# 139740  start  2018-06-20 14:25:13.010259+00                            NaN

# %% [markdown]
# #### 1.1.1 Посчитаем общее количество курсов в датасете

# %%
dt_main.course_id.nunique()
# Out:
# 15

# %% [markdown]
# #### 1.1.2 Количество модулей на каждом курсе

# %%
dt_main.groupby('course_title')['module_number'].nunique().to_frame()
# Out:
#                                      module_number
# course_title
# Excel Базовый                                    9
# Java-разработчик                                17
# Java-разработчик c нуля                          9
# JavaScript с нуля                               18
# PHP-разработчик с 0 до PRO. Часть 1              8
# SMM-маркетолог от А до Я                        11
# UX-дизайн                                       20
# Анимация интерфейсов                            21
# Веб-вёрстка для начинающих 2.0                   8
# Веб-дизайн PRO 2.0                              17
# Веб-дизайн Базовый                              17
# Веб-дизайн с нуля 2.0                           19
# Веб-разработчик                                 20
# Интернет-маркетолог от Ingate                   18
# Руководитель digital-проектов                   17

# %% [markdown]
# #### 1.1.3 Количество уроков в каждом модуле на каждом курсе

# %%
dt_main.groupby(['course_title', 'module_title'])['lesson_number'].nunique().to_frame()
# Out:
#                                                                                   lesson_number
# course_title                  module_title
# Excel Базовый                  Визуализация данных Excel                                      5
#                               Основной функционал Excel                                      11
#                               Основной функционал Excel (продолжение)                         7
#                               Сводные таблицы Excel                                           5
#                               Формулы и функции Excel. Более сложные формулы                  5
# ...                                                                                         ...
# Руководитель digital-проектов Решение факапов. Lean/TOC. Обзор.                               5
#                               Требовательность digital-продюсера                              4
#                               Управление временем                                             4
#                               Управление дизайнерами. Разработка дизайна по s...              7
#                               Экологичный путь менеджера                                      4
#
# [229 rows x 1 columns]

# %% [markdown]
# #### 1.1.4 Медианное количество уроков в модуле на каждом курсе,

# %%
dt_main.groupby(['course_title', 'module_title'])['lesson_number'].nunique().groupby('course_title').median().to_frame()
# Out:
#                                      lesson_number
# course_title
# Excel Базовый                                  5.0
# Java-разработчик                               7.0
# Java-разработчик c нуля                       13.0
# JavaScript с нуля                              7.0
# PHP-разработчик с 0 до PRO. Часть 1            4.0
# SMM-маркетолог от А до Я                       6.0
# UX-дизайн                                      3.5
# Анимация интерфейсов                           3.0
# Веб-вёрстка для начинающих 2.0                 7.0
# Веб-дизайн PRO 2.0                             5.0
# Веб-дизайн Базовый                             3.0
# Веб-дизайн с нуля 2.0                          4.0
# Веб-разработчик                                2.0
# Интернет-маркетолог от Ingate                  6.5
# Руководитель digital-проектов                  5.0

# %% [markdown]
# #### 1.1.5 количество учеников на каждом курсе

# %%
dt_main.groupby('course_title')['student_id'].nunique().to_frame()
# Out:
#                                      student_id
# course_title
# Excel Базовый                               782
# Java-разработчик                            763
# Java-разработчик c нуля                     581
# JavaScript с нуля                           966
# PHP-разработчик с 0 до PRO. Часть 1         854
# SMM-маркетолог от А до Я                    506
# UX-дизайн                                  1151
# Анимация интерфейсов                        598
# Веб-вёрстка для начинающих 2.0             2004
# Веб-дизайн PRO 2.0                         1711
# Веб-дизайн Базовый                          518
# Веб-дизайн с нуля 2.0                      2014
# Веб-разработчик                             628
# Интернет-маркетолог от Ingate              2168
# Руководитель digital-проектов               685

# %% [markdown]
# ##### 1.1.6 Минимальный, максимальный, средний, медианный возраст студентов

# %%
# приведём колонку birthday к формату дат
dt_students['birthday'] = pd.to_datetime(dt_students.birthday, yearfirst=True, dayfirst=False, format='%Y-%m-%d') 
# убираем непреобразованные значения
dt_students.dropna(subset=['birthday'], inplace=True)
# сброс индексов и перезапись
dt_students.reset_index(drop=True, inplace=True) 
dt_students
# Out:
#           id_                                id              city   birthday
# 0        7503  6c3e52be632fc50de9640147e4017dcd            Москва 1979-10-23
# 1       11070  35a36d90b745992b59085c8d54a072e7        Красноярск 1991-08-15
# 2       11756  37e8e8179295ae764524223086b0b568            Москва 1987-08-24
# 3       13568  fb10649db552c5f451bea45ed754d428   Санкт-Петербург 1988-07-16
# 4       15112  d15a188c90bb4d83957ac14de78fada4   Санкт-Петербург 1991-01-16
# ...       ...                               ...               ...        ...
# 11350  116725  3d7d520c6d739fc8cb844ebdc305743b            Москва 1990-02-21
# 11351  117886  4bc5e1606b9596cdfe2831c2abf91153        Кошкарагай 1919-01-01
# 11352  119731  859b49d2953c191275061f41f1ba09be         Краснодар 1990-01-03
# 11353  122651  2ea7f5c3346ec6b9b58d7ac15fa9ad61         Хабаровск 1993-04-16
# 11354  123277  67e72fd4f8810c633c461b01deccadb5  Санкт-Петербурге 1999-02-10
#
# [11355 rows x 4 columns]

# %%
from dateutil.relativedelta import relativedelta
today = pd.Timestamp.today() # текущая дата
# вычисляем возраст студентов по дате рождения
age = lambda x: relativedelta(today, x).years
# добавление в новый столбец age
dt_students['age'] = dt_students.birthday.apply(age)
dt_students.head()
# Out:
#      id_                                id             city   birthday  age
# 0   7503  6c3e52be632fc50de9640147e4017dcd           Москва 1979-10-23   41
# 1  11070  35a36d90b745992b59085c8d54a072e7       Красноярск 1991-08-15   29
# 2  11756  37e8e8179295ae764524223086b0b568           Москва 1987-08-24   33
# 3  13568  fb10649db552c5f451bea45ed754d428  Санкт-Петербург 1988-07-16   32
# 4  15112  d15a188c90bb4d83957ac14de78fada4  Санкт-Петербург 1991-01-16   30

# %%
#вывод результатов
dt_students.age.apply(['min', 'max', 'mean', 'median']).to_frame()
# Out:
#                age
# min    -178.000000
# max     136.000000
# mean     30.550506
# median   30.000000

# %%
dt_students.drop(np.where(dt_students.age.lt(10) | dt_students.age.gt(90))[0], inplace=True)

# %%
#вывод результатов
dt_students.age.apply(['min', 'max', 'mean', 'median']).to_frame()
# Out:
#               age
# min     11.000000
# max     86.000000
# mean    30.722685
# median  30.000000

# %% [markdown]
# ##### 1.1.7 Минимальный, максимальный, средний, медианный возраст студентов на каждом курсе

# %% [markdown]
# Чтобы посчитать необходимо сначала соединить датафрейм dt_students с dt_main по столбцу students_id

# %%
dt_students = dt_students.drop(columns=['id_'])

# %%
dt_students.rename(columns={'id':'student_id'}, inplace=True) # переименуем колонку для обьединения
dt_merge = dt_main.merge(dt_students,how='left',on='student_id') # обьеденим 
dt_merge[['course_title', 'age']].groupby('course_title').agg(['min', 'max', 'mean', 'median']) # сгруппируем
# Out:
#                                       age
#                                       min   max       mean median
# course_title
# Excel Базовый                        17.0  62.0  34.213375   34.0
# Java-разработчик                     15.0  65.0  30.750676   30.0
# Java-разработчик c нуля              16.0  56.0  30.533100   30.0
# JavaScript с нуля                    14.0  60.0  29.306153   29.0
# PHP-разработчик с 0 до PRO. Часть 1  14.0  76.0  31.954933   30.0
# SMM-маркетолог от А до Я             18.0  53.0  29.692461   29.0
# UX-дизайн                            16.0  86.0  31.378768   31.0
# Анимация интерфейсов                 16.0  52.0  30.751111   30.0
# Веб-вёрстка для начинающих 2.0       14.0  60.0  29.483915   28.0
# Веб-дизайн PRO 2.0                   16.0  60.0  29.479884   28.0
# Веб-дизайн Базовый                   16.0  52.0  29.432649   29.0
# Веб-дизайн с нуля 2.0                16.0  76.0  29.277053   28.0
# Веб-разработчик                      14.0  52.0  28.424155   28.0
# Интернет-маркетолог от Ingate        17.0  59.0  32.470769   31.0
# Руководитель digital-проектов        21.0  48.0  32.998833   32.0

# %% [markdown]
# #### 1.2 Постройте bar-chart, отражающий количество студентов на каждом курсе. Ticks нужно развернуть так, чтобы они были читаемы

# %%
# Отсортированныйп по убыванию и сгруппируем по курсам
sum_students_courses = dt_merge.groupby('course_title').student_id.nunique().sort_values(ascending=False)
sum_students_courses
# Out:
# course_title
# Интернет-маркетолог от Ingate          2168
# Веб-дизайн с нуля 2.0                  2014
# Веб-вёрстка для начинающих 2.0         2004
# Веб-дизайн PRO 2.0                     1711
# UX-дизайн                              1151
# JavaScript с нуля                       966
# PHP-разработчик с 0 до PRO. Часть 1     854
# Excel Базовый                           782
# Java-разработчик                        763
# Руководитель digital-проектов           685
# Веб-разработчик                         628
# Анимация интерфейсов                    598
# Java-разработчик c нуля                 581
# Веб-дизайн Базовый                      518
# SMM-маркетолог от А до Я                506
# Name: student_id, dtype: int64

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
          '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

plt.figure(figsize=(20,8))
plt.xticks(rotation=75)
plt.title("Количество студентов на каждом курсе")
plt.bar(sum_students_courses.index,sum_students_courses.values,color=colors,alpha=0.5)
plt.show()

# %% [markdown]
# #### 1.3 Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий количество студентов на каждом курсе. График должен иметь заголовок. Значения должны быть отсортированы. Цвет столбцов должен содержать информацию о сфере, к которой относится курс (то есть нужна легенда). Прозрачность должна стоять на отметке 0.1. На график должна быть нанесена линия медианы. У медианы должен быть свой цвет. Рамки у графика быть не должно ⭐

# %% [markdown]
# Cоздаём новый дафтафрейм Сгруппируем по названиями и сферам курсов

# %%
dt_students = dt_merge.groupby(['course_title', 'field']).student_id\
                           .nunique()\
                           .sort_values(ascending=False)\
                           .to_frame()\
                           .reset_index(1)\
                           .rename(columns={'student_id':'students'})
dt_students
# Out:
#                                            field  students
# course_title
# Интернет-маркетолог от Ingate          Marketing      2168
# Веб-дизайн с нуля 2.0                     Design      2014
# Веб-вёрстка для начинающих 2.0       Development      2004
# Веб-дизайн PRO 2.0                        Design      1711
# UX-дизайн                                 Design      1151
# JavaScript с нуля                    Development       966
# PHP-разработчик с 0 до PRO. Часть 1  Development       854
# Excel Базовый                           Business       782
# Java-разработчик                     Development       763
# Руководитель digital-проектов           Business       685
# Веб-разработчик                      Development       628
# Анимация интерфейсов                      Design       598
# Java-разработчик c нуля              Development       581
# Веб-дизайн Базовый                        Design       518
# SMM-маркетолог от А до Я               Marketing       506

# %%
#Рассчитаем медианное количество студентов по всем курсам 
median_num_students = dt_students.students.median()
median_num_students
# Out:
# 782.0

# %%
import seaborn as sns # импортируем библиотерку для удобного отображения графика
palette = plt.get_cmap('Set2')

field_color = dict(zip(dt_merge.field.unique(), plt.get_cmap('tab10',10).colors[[2,3,0,1]]))

plt.figure(figsize=(20,8))
ax = plt.axes()
plt.title("Количество студентов на каждом курсе")
plt.xticks(np.arange(0, max(sum_students_courses+200), 200))
plt.tick_params(labelsize=16)

sns.barplot('students', dt_students.index,
            hue='field',
            hue_order=field_color.keys(),
            dodge=False,
            data = dt_students, alpha=0.5,
            palette=field_color)\
            .set(ylabel=None, xlabel=None)

plt.axvline(x=median_num_students, ls='-', label='Median', color='r') # добавляем медианное значение вертикальной линией
plt.grid(axis='x', color='.95')
plt.legend(fontsize=14)
plt.show()

# %% [markdown]
# #### 1.4 На основании рассчитанных значений опишите данные (описание должно быть полным и покрывать все полученные выше метрики)

# %% [markdown]
# <b> Общее количество курсов в датасете: </b> 15 курсов<br>
# <b> Количество модулей на каждом курсе:</b> От 8 модулей (Веб-вёрстка для начинающих 2.0 и PHP-разработчик с 0 до PRO. Часть 1) до 21 модулей (Анимация интерфейсов) в зависимости от курса.<br>
# <b> Медианное количество уроков в модуле на каждом курсе:</b> от 2.0 ("Веб-разработчик") до 10 ("Java-разработчик с нуля") <br>
# <b> Количество учеников на каждом курсе:</b><br>
# Два самых не популярных курса
# * SMM-маркетолог от А до Я  506
# * Веб-дизайн Базовый    518
# <br>
# <b> Минимальный, максимальный, средний, медианный возраст студентов:</b><br>
#  * Средний возраст учеников курсов 30-32 лет. <br>
# <b> Минимальный, максимальный, средний, медианный возраст студентов на каждом курсе:</b><br>
# * Предпочтений курсов в завсимости от возрастов не наблюдается. "Excel Базовый" выбирают люди более старшего возраста

# %% [markdown]
# ## 2. Расчет потенциальной нагрузки на преподавателей
#
# 1. **(p)** Рассчитать прирост студентов на каждом курсе в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно). Считать дату начала прохождения курса студентом по дате начала первой домашней работы.
# 2. **(m)** На основании первого пункта построить line-graph с приростом студентов в каждом месяце для каждого курса. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы.
# 3. **(m)** На основании первого пункта построить line-graph с несколькими линиями, отражающими прирост студентов в каждом месяце для каждого курса. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая прирост, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 4. **(p)** Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно) для каждого курса. Учитывать, что выполнение домашнего задания может перетекать из одного месяца в другой (такие дз надо включать в общее число прогрессов для всех месяцев, которые покрывает срок выполнения этих дз)
# 5. **(m)** Построить line-graph по четвертому пункту. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы
# 6. **(m)** Построить один line-graph для всех курсов по четвертому пункту. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая количество прогрессов, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 7. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
import datetime


df_increase=dt_main[['course_id','course_title', 'student_id', 'start_date', 'is_homework']]
df_increase = df_increase[(df_increase['is_homework']==True)]
df_increase['start_month'] =df_increase['start_date'].apply(lambda date: datetime.datetime.strptime(date[0:7], '%Y-%m'))
df_increase=df_increase.groupby(['course_id','course_title', 'student_id'])['start_month'].min().reset_index()
df_increase['growth'] =1
df_increase = df_increase.groupby(['course_id','course_title','start_month'])['growth'].sum().reset_index()
df_increase = df_increase.sort_values(by='start_month')


df_increase
# Out:
#                             course_id                   course_title  \
# 56   480d25ad36878fce09e7aada316ba1a6                Веб-разработчик
# 191  dad6f6ffc086caa89e2f40c28a9c7490                      UX-дизайн
# 38   17013cd19d25cb3f28dc1b2683721bb9             Веб-дизайн Базовый
# 192  dad6f6ffc086caa89e2f40c28a9c7490                      UX-дизайн
# 57   480d25ad36878fce09e7aada316ba1a6                Веб-разработчик
# ..                                ...                            ...
# 212  dad6f6ffc086caa89e2f40c28a9c7490                      UX-дизайн
# 159  bf27a4bf4ada4c756451703ea62a914f  Интернет-маркетолог от Ingate
# 173  c9fcb746d51e41bc5a217002d081454b             Веб-дизайн PRO 2.0
# 76   480d25ad36878fce09e7aada316ba1a6                Веб-разработчик
# 243  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
#
#     start_month  growth
# 56   2016-03-01       1
# 191  2016-11-01       2
# 38   2017-03-01       2
# 192  2017-04-01       1
# 57   2017-04-01       1
# ..          ...     ...
# 212  2019-07-01      18
# 159  2019-07-01      91
# 173  2019-07-01      40
# 76   2019-07-01       4
# 243  2019-07-01      21
#
# [244 rows x 4 columns]

# %%
courses_list = df_increase.groupby(['course_title', 'course_id'])['growth'].sum().reset_index()
for index, row in courses_list.iterrows():
    fig, subplot = plt.subplots()
    fig.set_size_inches(9, 5, forward=True)
    course_data = df_increase[(df_increase['course_id']==row.course_id)]
    
    start_date = course_data['start_month'].min()
    end_date = course_data['start_month'].max()
    
    m = pd.date_range(start_date, end_date, freq='MS')
    
    for month in m:
        if(course_data[(course_data['start_month']==month)]['start_month'].size==0):
            course_data.loc[month]= [row.course_id,row.course_title,month, 0]
    
    course_data = course_data.sort_values(by='start_month')
    subplot.set_title(row.course_title)
    subplot.plot(course_data['start_month'], course_data['growth'])
    
    subplot.xaxis.set_ticks(m.values)
    
    subplot.set_ylabel('Новые студенты')
    subplot.set_xlabel('месяц')
    plt.xticks(rotation='vertical')

plt.show()
# Out:
# C:\Users\sean2\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\sean2\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\sean2\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\sean2\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\sean2\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
import matplotlib.ticker as ticker

courses_list = df_increase.groupby(['course_title', 'course_id'])['growth'].sum().reset_index()
 
start_date = datetime.datetime.strptime("2016-03", '%Y-%m')
end_date = datetime.datetime.strptime("2019-07", '%Y-%m')
  
m = pd.date_range(start_date, end_date, freq='MS')

fig, subplot = plt.subplots()
fig.set_size_inches(18.5, 10.5, forward=True)
subplot.grid()
subplot.tick_params(labelbottom = True)
subplot.minorticks_on()

for index, row in courses_list.iterrows(): 
    course_data = df_increase[(df_increase['course_id']==row.course_id)]
    start_date = course_data['start_month'].min()
    end_date = course_data['start_month'].max()
    
    m_i = pd.date_range(start_date, end_date, freq='MS')
    for month in m_i:
        if(course_data[(course_data['start_month']==month)]['start_month'].size==0):
            course_data.loc[month]= [row.course_id,row.course_title,month, 0]
    course_data = course_data.sort_values(by='start_month')
    subplot.plot(course_data['start_month'], course_data['growth'])

subplot.set_title('Прирост студентов по курсам')
subplot.spines['top'].set_visible(False)
subplot.spines['right'].set_visible(False)
subplot.set_ylabel('Число новых студентов')
subplot.xaxis.set_ticks(m.values)
plt.legend(courses_list['course_title'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\sean2\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\sean2\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\sean2\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\sean2\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\sean2\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %%
new_progress = []

df_courses_list = dt_main.groupby(["course_id", "course_title"])['module_number'].nunique().reset_index()

df_progress1=dt_main[['course_id','course_title', 'start_date', 'finish_date', 'is_homework']]
df_progress1 = df_progress1[(df_progress1['is_homework']==True)]

df_progress1['finish_date']=df_progress1['finish_date'].fillna(df_progress1['start_date'])

df_progress1['start_date']=df_progress1['start_date'].apply(lambda x: x[0:7])
df_progress1['finish_date']=df_progress1['finish_date'].apply(lambda x: x[0:7])
df_progress1['count'] = 1

df_progress1 = df_progress1.groupby(['course_id','course_title', 'start_date', 'finish_date']).sum().reset_index()

start_date = datetime.datetime.strptime("2016-03", '%Y-%m')
end_date = datetime.datetime.strptime("2019-07", '%Y-%m')

arr_coupses = df_courses_list[['course_id','course_title']].values

for index,item in enumerate(arr_coupses):
    for month in pd.date_range(start_date, end_date, freq='MS'):
        new_progress.append([item[0],item[1], month.date().strftime('%Y-%m')])

df_new_progress = pd.DataFrame(new_progress, columns=['course_id','course_title','date'])

df_new_progress.set_index(['course_id','date'], inplace=True)
df_new_progress['count'] = 0

for data in df_progress1.values:
    for month in pd.date_range(data[2], data[3], freq='MS'):    
        df_new_progress.loc[(data[0], month.date().strftime('%Y-%m')), 'count'] +=data[4]      

df_new_progress
# Out:
#                                                   course_title  count
# course_id                        date
# 04ba6d0b40670c43a209141fa01fa784 2016-03  Анимация интерфейсов    0.0
#                                  2016-04  Анимация интерфейсов    0.0
#                                  2016-05  Анимация интерфейсов    0.0
#                                  2016-06  Анимация интерфейсов    0.0
#                                  2016-07  Анимация интерфейсов    0.0
# ...                                                        ...    ...
# e9bb9205eeed307ee7cbaa08bfd166c3 2019-03     JavaScript с нуля  381.0
#                                  2019-04     JavaScript с нуля  351.0
#                                  2019-05     JavaScript с нуля  368.0
#                                  2019-06     JavaScript с нуля  359.0
#                                  2019-07     JavaScript с нуля  183.0
#
# [615 rows x 2 columns]

# %%
df_new_progress.to_csv('Data_1/Data/progress_new.csv')

# %%
courses_list = dt_main.groupby(["course_id", "course_title"])['module_number'].nunique().reset_index()
df_new_progress = df_new_progress.reset_index()
#ourses_list = df_increase.groupby(['course_title', 'course_id'])['dummy'].sum().reset_index()

for index, row in courses_list.iterrows():
    fig, subplot = plt.subplots()
    fig.set_size_inches(10.5,6.5 , forward=True)
    subplot.grid()
    course_data = df_new_progress[(df_new_progress['course_id'] == row.course_id)]
    subplot.set_title(row.course_title)
    subplot.plot(course_data['date'], course_data['count'])
    subplot.set_ylabel('Прогресс')
    subplot.set_xlabel('Месяц')
    plt.xticks(rotation='vertical')

plt.show()

# %%
courses_list = dt_main.groupby(["course_id", "course_title"])['module_number'].nunique().reset_index()

fig, subplot = plt.subplots()
fig.set_size_inches(18.5, 10.5, forward=True)
subplot.grid()
for index, row in courses_list.iterrows():
    course_data = df_new_progress[(df_new_progress['course_id'] == row.course_id)] 
    
    subplot.plot(course_data['date'], course_data['count'])
plt.legend(courses_list['course_title'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Выводы
#  * В курсе веб верстка для начинающих выл большой прирост студентов в июле 2018
#  * Прогресс выполнения заданий связан с приростом студентов. Т.е прогресс вырос в январе 2019го.
#  * Так же был всплеск в декабре 2019. Похоже на распродажу

# %% [markdown]
# ## 3. Выявление проблемных модулей
#
# 1. **(p)** Рассчитать минимальное, максимальное, среднее, медианное время прохождения каждого модуля (разность между временем начала и окончания выполнения домашней работы) для каждого курса. Если домашних заданий в модуле несколько, то считать разность между временем начала выполнения первой домашней работы и временем окончания выполнения последней домашней работы в модуле
# 2. **(m)** На основании первого пункта построить line-graph с медианным временем прохождения каждого модуля для каждого курса. 15 графиков. Графики должны иметь заголовки
# 3. **(p)**  Чтобы выявить сезонность, посчитать медианное время выполнения домашней работы по месяцам (12 месяцев, январь-декабрь) для каждого курса.
# 4. **(m)** На основании третьего пункта построить line-graph, на который будут нанесены линии для каждого курса с медианным временем выполнения домашней работы по месяцам. 15 линий на графике. График должен иметь заголовок. Ось, отражающая время прохождения, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно  ⭐
# 5. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
import pandas as pd

df_main_1 = dt_main.copy()

df_main_1 = df_main_1[(df_main_1['is_homework']==True)]

df_copy = df_main_1.groupby(['course_id', 'module_number','student_id'])['status'].agg({'nunique', 'max'}).reset_index()
df_copy = df_copy[(df_copy['nunique']==1)&(df_copy['max']=='done')]

df_main_1 = df_copy.merge(df_main_1, left_on=["student_id", 'course_id', 'module_number'], right_on=["student_id",'course_id', 'module_number'], copy=False)

df_main_1['start_date'] = pd.to_datetime(df_main_1['start_date'])
df_main_1['finish_date'] = pd.to_datetime(df_main_1['finish_date'])

df_main_1 = df_main_1[(df_main_1['finish_date'] > df_main_1['start_date'])]

df_result = df_main_1.groupby(['course_id', 'course_title', 'module_number','student_id']).agg({'start_date': 'min', 'finish_date':'max'}).reset_index()
df_result['difference'] = (df_result['finish_date'] - df_result['start_date']).dt.total_seconds()/86400
#df_result= df_result.sort_values(by=['course_id','module_number','difference'])
df_result = df_result[df_result['difference']>1]
df_result = df_result.groupby(['course_id', 'course_title', 'module_number'])['difference'].agg({'min','max','median','mean'}).reset_index()

df_result
# Out:
#                             course_id          course_title  module_number  \
# 0    04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов              1
# 1    04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов              2
# 2    04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов              3
# 3    04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов              4
# 4    04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов              5
# ..                                ...                   ...            ...
# 185  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля             13
# 186  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля             14
# 187  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля             15
# 188  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля             16
# 189  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля             18
#
#           mean         max     median        min
# 0    18.631996  259.747002   4.508665   1.040743
# 1    19.358042  291.373780   6.452551   1.025306
# 2    38.531509  319.436511  10.975594   1.049318
# 3    19.722227  173.652884   8.972523   1.400095
# 4    17.921345  160.386758   7.611458   1.095725
# ..         ...         ...        ...        ...
# 185   6.705776  124.992976   3.270034   1.033343
# 186  12.020574  127.055000   6.736162   1.009554
# 187  17.949562   88.502526  11.929509   3.970032
# 188  23.064997  107.947336  17.135044   2.163159
# 189  45.646816   92.497922  41.971288  10.529740
#
# [190 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

courses_list = dt_main.groupby(["course_id", "course_title"])['module_number'].nunique().reset_index()

for index, row in courses_list.iterrows():
    fig, subplot = plt.subplots()
    fig.set_size_inches(10.5,6.5 , forward=True)
    subplot.grid()
    course_data = df_result[(df_result['course_id'] == row.course_id)]
    subplot.set_title(row.course_title)
    subplot.plot(course_data['module_number'], course_data['mean'])  
    subplot.xaxis.set_ticks((course_data['module_number'].values))
    
    subplot.set_ylabel('Медианное время завершения домашней работы в днях')
    subplot.set_xlabel('Номер модуля')
    plt.xticks(rotation='vertical')

plt.show()

# %%
df_main_2 = dt_main.copy()

df_main_2 = df_main_2[df_main_2['is_homework']==True]
df_main_2 = df_main_2[df_main_2['status']=='done']

df_main_2 = df_main_2.dropna()
df_main_2['finish_month'] = df_main_2['finish_date'].apply(lambda x: x[0:7]) 

df_main_2['start_date'] = pd.to_datetime(df_main_2['start_date'])
df_main_2['finish_date'] = pd.to_datetime(df_main_2['finish_date'])

df_main_2 = df_main_2[(df_main_2['finish_date'] > df_main_2['start_date'])]

df_result = df_main_2.groupby(['course_id', 'course_title', 'finish_month','progress_id']).agg({'start_date': 'min', 'finish_date':'max'}).reset_index()
df_result['difference'] = (df_result['finish_date'] - df_result['start_date']).dt.total_seconds()/86400
df_result = df_result.groupby(['course_id', 'course_title', 'finish_month'])['difference'].agg({'median'}).reset_index()

df_result['finish_month'] = pd.to_datetime(df_result['finish_month'])

df_result
# Out:
#                             course_id          course_title finish_month  \
# 0    04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов   2018-02-01
# 1    04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов   2018-03-01
# 2    04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов   2018-04-01
# 3    04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов   2018-05-01
# 4    04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов   2018-06-01
# ..                                ...                   ...          ...
# 250  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля   2019-03-01
# 251  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля   2019-04-01
# 252  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля   2019-05-01
# 253  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля   2019-06-01
# 254  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля   2019-07-01
#
#         median
# 0     0.864519
# 1     8.749890
# 2     8.484846
# 3    13.065224
# 4     9.361831
# ..         ...
# 250  16.682180
# 251  20.689468
# 252  21.205038
# 253  27.643430
# 254  13.632184
#
# [255 rows x 4 columns]

# %%
courses_list = dt_main.groupby(["course_id", "course_title"])['module_number'].nunique().reset_index()

start_date = datetime.datetime.strptime("2016-03", '%Y-%m')
end_date = datetime.datetime.strptime("2019-07", '%Y-%m')
  
m = pd.date_range(start_date, end_date, freq='MS')

fig, subplot = plt.subplots()
fig.set_size_inches(18.5, 10.5, forward=True)
subplot.grid()
for index, row in courses_list.iterrows():
    course_data = df_result[(df_result['course_id'] == row.course_id)] 
    
    start_date = course_data['finish_month'].min()
    end_date = course_data['finish_month'].max()
    
    m_1 = pd.date_range(start_date, end_date, freq='MS')
    
    for month in m_1:
        if(course_data[(course_data['finish_month']==month)]['finish_month'].size==0):
            course_data.loc[month]= [row.course_id,row.course_title,month, 0]
            
    course_data = course_data.sort_values(by='finish_month')
    subplot.plot(course_data['finish_month'], course_data['median'])
    
subplot.xaxis.set_ticks(df_result.groupby('finish_month').sum().reset_index()['finish_month'].values)
plt.legend(courses_list['course_title'])
plt.xticks(rotation=45)

subplot.set_title('Медианное время прохождения домашнего задания')
subplot.spines['top'].set_visible(False)
subplot.spines['right'].set_visible(False)
subplot.set_ylabel('Время прохождения в днях')
subplot.xaxis.set_ticks(m.values)

plt.show()
# Out:
# C:\Users\sean2\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\sean2\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\sean2\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\sean2\anaconda3\lib\site-packages\pandas\core\indexing.py:671: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# * Максимальное число сдач в феврале - марте
# * В большинстве курсов время выполнения заданий некоторых больше чем остальных. Это связано с тем, что чем сложнее домашка, тем больше времени нужно для сдачи

# %% [markdown]
# ## 4. Расчет конверсии
#
# 1. **(p)** Посчитать конверсию перехода студентов из одного модуля в другой на каждом курсе. Формула: отношение количества студентов, приступивших к выполнению домашнего задания в этом модуле (если дз в модуле несколько, то считать по первому дз в модуле), к количеству студентов, сдавших задание в предыдущем модуле (если дз в модуле несколько, то считать по последнему дз в модуле).
# 2. **(m)** Постройте bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. График должен иметь заголовок. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. 15 графиков. Графики должны иметь заголовки. Ticks должны содержать номер и название модуля. Цвет столбцов графиков должен содержать информацию о сфере, к которой относится курс (нужна легенда). Прозрачность должна стоять на отметке 0.1. На графики должна быть нанесена линия медианы конверсии для каждого курса. У медианы должен быть свой цвет. Рамок у графиков быть не должно ⭐
# 4. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
df_main_3 = dt_main.copy()
 
df_main_3 = df_main_3[df_main_3['is_homework']==True]
df_main_3['start_count'] = 1 

df_main_3['finish_count'] = df_main_3['status']=='done'
df_main_3['finish_count'] = df_main_3['finish_count'].astype(int)
#df_main_3 = df_main_3[(df_main_3['status']=='done')]
df_main_3
df_result =  df_main_3.groupby(['course_id', 'course_title', 'module_number']).agg({'finish_count':'sum', 'start_count':'sum'}).reset_index()

df_result['finish_count_prev'] = 0

for i in range(1, df_result.shape[0]):
    df_result.iloc[i,5] = df_result.iloc[i-1,3]
    
df_result['conv'] = df_result['start_count']/df_result['finish_count_prev'] 

df_result = df_result[(df_result['module_number']!=1)]

df_result
# Out:
#                             course_id          course_title  module_number  \
# 1    04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов              2
# 2    04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов              3
# 3    04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов              4
# 4    04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов              5
# 5    04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов              7
# ..                                ...                   ...            ...
# 186  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля             13
# 187  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля             14
# 188  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля             15
# 189  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля             16
# 190  e9bb9205eeed307ee7cbaa08bfd166c3     JavaScript с нуля             18
#
#      finish_count  start_count  finish_count_prev      conv
# 1             218          272                277  0.981949
# 2             144          216                218  0.990826
# 3             120          151                144  1.048611
# 4              97          112                120  0.933333
# 5              71           92                 97  0.948454
# ..            ...          ...                ...       ...
# 186            58           63                 61  1.032787
# 187            50           58                 58  1.000000
# 188            37           50                 50  1.000000
# 189            23           40                 37  1.081081
# 190            13           27                 23  1.173913
#
# [177 rows x 7 columns]

# %%
courses_list = dt_main.groupby(["course_id", "course_title"])['module_number'].nunique().reset_index()

x = np.arange(-1/16*11,1/16*11,1/16)  # the label locations

width = 1/15  # the width of the bars

fig, subplot = plt.subplots()
fig.set_size_inches(18.5, 10.5, forward=True)

for index, row in courses_list.iterrows():
    course_data = df_result[(df_result['course_id'] == row.course_id)]
    subplot.bar(
        course_data['module_number'].values+x[index], 
              course_data['conv'].values, width,)

subplot.xaxis.set_ticks(range(0, 22, 1))
plt.legend(courses_list['course_title'])
plt.show()

# %% [markdown]
# * В курсе web-дизайн <Базовый базовый очень много учеников присупивших ко второму ДЗ без здачи первого.
# * 4м модулем Java разработка с нуля и 6м модулем SMM маркетинг такая же ситуация\
# * 10й по Веб дизайн базовый, 17й по Интернет маркетингу - самые плохие по конверсиям

# %% [markdown]
# ## 5. Метрика успеваемости
#
# &nbsp;&nbsp;&nbsp;&nbsp;*(необязательное задание)*
#
# Иногда студенты берут курсы, которые оказываются для них неподъемными. Это может быть как по причинам недостаточной изначальной подготовки, так и по причинам, связанным с низкой мотивацией студента. Для улучшения качества контента полезно выявить причину. На основании имеющихся данных придумайте метрику успеваемости студента. **Обоснуйте ее.** Выявите таких студентов на каждом курсе, чтобы предоставить продюсерам список проблемных студентов.

# %%
df_main_4 = dt_main.copy()
 
df_main_4['done'] = df_main_4['status']=='done'
df_main_4['done'] = df_main_4['done'].astype(int)

df_main_4 = df_main_4.groupby('student_id').agg({'status':'count', 'done':'sum'}).reset_index()

df_main_4['perf'] = df_main_4['done']/df_main_4['status']

df_main_4.sort_values(by=['perf','status'],  ascending=[True, False])
# Out:
#                             student_id  status  done  perf
# 6004  a002a005048ae8cc2ff6cdc120cf3aad      10     0   0.0
# 1233  20804c32da13576833a5124961cd08f1       9     0   0.0
# 4045  6cdeb0b754b18270d7654a02d4a9a5d8       6     0   0.0
# 9558  fa00ce7a14ab3a06a6397f6359b32e27       6     0   0.0
# 1961  349e069edb6e004408f968eb009036d0       5     0   0.0
# ...                                ...     ...   ...   ...
# 9224  f1ec0332c0190893a180bc4b1cb90bce       1     1   1.0
# 9300  f3a696a85b074788cee342ec48348cab       1     1   1.0
# 9478  f85035fb9fea3d33ea8a4846ee9e9cc0       1     1   1.0
# 9656  fc72c02ad6d67190ff2d7f40a26f3463       1     1   1.0
# 9678  fcdf7fff8ae02686a0a900035f343b99       1     1   1.0
#
# [9794 rows x 4 columns]

# %% [markdown]
# * Метрика зависимости  количества начатых модулей к количеству завершенных отсортирована по метрике, а затем по количеству начатых заданий. Чем больше студент начал модулей и меньше при этом закончил, тем меньше у него успеваемость.
