# %% [markdown]
# ## Домашнее задание. Функции одной переменной, их свойства и графики.
#
#
# Домашнее задание к модулю состоит из двух частей. В первой части вы найдете пять графиков и 5 функций. Укажите, какой функции какой график соответствует.
# 	Во второй части дан набор функций. Исследуйте их на четность/нечетность, найдите их нули и промежутки знакопостоянства. Также, с помощью графиков, определите промежутки возрастания/убывания этих функций. Это легко сделать для линейной и показательной функций, для корня и логарифма немного сложнее, а для решения задачи с параболой нужно будет немного подумать. Если у вас нет желания поломать голову, находить промежутки возрастания/убывания параболы необязательно. Для тех, кто решит этим заняться, есть подсказка в текстовом описании под видео. <br><br>
# 	На проверку пришлите ноутбук с выполненным исследованием. <br>

# %% [markdown]
# ### Задание 1.
#
# а. $4x+5$ <br>
# б. $4x^2+4x+10$ <br>
# в. $100log(x)$ <br>
# г. $200\sqrt x$ <br>
# д. $100e^{0.2x}$ <br>
#
# 1. ![pic1.jpg](1.jpg)
# 2. ![pic2.png](2.jpg)
# 3. ![pic3.png](3.jpg)
# 4. ![pic4.png](4.jpg)
# 5. ![pic5.png](5.jpg)
#
#
# **Ответ:**
#
# a -  5<br>
# b -  3<br>
# в -  1<br>
# г - 4<br>
# д - 2<br>

# %% [markdown]
# ### Задание 2. Проведите исследование полученных функций.
#
# 1. $5x + 1.5$
# 2. $2e^{0.2x}-1$
# 3. $3\sqrt x - 15$
# 4. $2\log(x) + 5$
# 5. $-5x^2 - 10x + 100$

# %%
from sympy import *
from sympy.solvers.inequalities import solve_univariate_inequality
init_printing(use_unicode=False,wrap_line=False,no_global=True)

# %%
x = Symbol('x')
one = 5*x+1.5
plot(one)
print(one.subs(x,100))
print(one.subs(x,-100))
print('Функция ни четная, и ни нечетная')
print('Нули функции',solve(one))
print('Больше нуля ',solve_univariate_inequality(one>0,one))
print('Меньше нуля',solve_univariate_inequality(one<0,one))
print('Возрастает на всем участке')
# Out:
# 501.500000000000
# -498.500000000000
# Функция ни четная, и ни нечетная
# Нули функции [-0.300000000000000]
# Больше нуля  (0 < 5*x + 1.5) & (5*x + 1.5 < oo)
# Меньше нуля (-oo < 5*x + 1.5) & (5*x + 1.5 < 0)
# Возрастает на всем участке

# %%
import math

# %%
two = 2*x*E**(0.2*x)-1
plot(two)
print(two.subs(x,100))
print(two.subs(x,-100))
print('Функция ни четная, и ни нечетная')
print('Нули функции',solve(two))
print('Возрастает на всем участке')
# Out:
# 97033039080.9581
# -1.00000041223072
# Функция ни четная, и ни нечетная
# Нули функции [0.456382635804311]
# Возрастает на всем участке

# %%
three = 3*sqrt(x)-15
plot(three)
print('Функция ни четная, и ни нечетная')
print('Нули функции',solve(three))
# Out:
# Функция ни четная, и ни нечетная
# Нули функции [25]

# %%
four = 2*log(x) +5 
plot(four)
print('Функция ни четная, и ни нечетная')
print('Нули функции',solve(four))
# Out:
# Функция ни четная, и ни нечетная
# Нули функции [exp(-5/2)]

# %%
five = -5*x**2 - 10*x + 100
plot(five)
print(five.subs(x,100))
print(five.subs(x,-100))
print('Функция ни четная, и ни нечетная')
print('Нули функции',solve(five))
# Out:
# -50900
# -48900
# Функция ни четная, и ни нечетная
# Нули функции [-1 + sqrt(21), -sqrt(21) - 1]
